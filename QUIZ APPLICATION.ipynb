# %% [markdown]
# # PYTHON QUIZ APPLICATION

# %%
# Quiz Application: Python Programming Quiz
# Overview: This application is designed to test the user's knowledge of Python programming fundamentals through a series of 50 multiple-choice questions. 
# It aims to reinforce learning and assess understanding in various areas such as syntax, data types, functions, error handling, object-oriented programming, and more.

# List of 50 Python quiz questions and answers
quiz_questions = [
    # Basic questions about Python
    {"question": "1. What is the correct file extension for Python files?",
     "options": ["A) .pyth", "B) .pt", "C) .py", "D) .pyt"], "answer": "C"},
    
    {"question": "2. Which keyword is used to create a function in Python?",
     "options": ["A) func", "B) def", "C) function", "D) define"], "answer": "B"},
    
    {"question": "3. What is the output of print(2 ** 3)?",
     "options": ["A) 5", "B) 6", "C) 8", "D) 9"], "answer": "C"},
    
    {"question": "4. How do you insert comments in Python code?",
     "options": ["A) // comment", "B) /* comment */", "C) # comment", "D) <!-- comment -->"], "answer": "C"},
    
    {"question": "5. Which of the following data types is immutable?",
     "options": ["A) List", "B) Dictionary", "C) Set", "D) Tuple"], "answer": "D"},
    
    # Operators and basic functions
    {"question": "6. What does the len() function do?",
     "options": ["A) Returns the length of an object", "B) Converts object to integer", "C) Sums up all elements", "D) Sorts the object"], "answer": "A"},
    
    {"question": "7. Which of the following is not a valid Python data type?",
     "options": ["A) List", "B) Set", "C) Integer", "D) Array"], "answer": "D"},
    
    {"question": "8. How do you start a loop in Python that will execute 5 times?",
     "options": ["A) for x in range(5):", "B) repeat(5)", "C) while x < 5:", "D) for x until 5"], "answer": "A"},
    
    {"question": "9. Which function is used to display text in Python?",
     "options": ["A) display()", "B) echo()", "C) print()", "D) write()"], "answer": "C"},
    
    {"question": "10. What does the 'break' keyword do in a loop?",
     "options": ["A) Pauses the loop", "B) Stops the loop", "C) Repeats the loop", "D) Skips an iteration"], "answer": "B"},

    # Data types and variables
    {"question": "11. What data type is used to store text?",
     "options": ["A) int", "B) str", "C) list", "D) bool"], "answer": "B"},
    
    {"question": "12. What will the following code print? print(type('Hello'))",
     "options": ["A) int", "B) str", "C) list", "D) float"], "answer": "B"},
    
    {"question": "13. Which of the following is a mutable data type?",
     "options": ["A) Tuple", "B) List", "C) String", "D) Integer"], "answer": "B"},
    
    {"question": "14. What is the output of print(3 * 'abc')?",
     "options": ["A) abcabcabc", "B) 9", "C) Error", "D) abcabc"], "answer": "A"},
    
    {"question": "15. What type of error is raised when dividing by zero?",
     "options": ["A) NameError", "B) ZeroDivisionError", "C) ValueError", "D) IndexError"], "answer": "B"},

    # More on functions and conditionals
    {"question": "16. Which statement is used to stop a loop?",
     "options": ["A) stop", "B) break", "C) quit", "D) exit"], "answer": "B"},
    
    {"question": "17. What does the 'return' keyword do in a function?",
     "options": ["A) Exits the loop", "B) Exits the program", "C) Exits the function", "D) Exits the module"], "answer": "C"},
    
    {"question": "18. How do you define a list in Python?",
     "options": ["A) [1, 2, 3]", "B) (1, 2, 3)", "C) {1, 2, 3}", "D) <1, 2, 3>"], "answer": "A"},
    
    {"question": "19. What is the output of print(bool(0))?",
     "options": ["A) True", "B) False", "C) Error", "D) 0"], "answer": "B"},
    
    {"question": "20. What is the correct way to declare a variable?",
     "options": ["A) x = 10", "B) let x = 10", "C) declare x = 10", "D) var x = 10"], "answer": "A"},

    # Dictionaries and sets
    {"question": "21. How do you create a dictionary in Python?",
     "options": ["A) dict()", "B) {}", "C) []", "D) ()"], "answer": "A"},
    
    {"question": "22. What is the output of print(type({1, 2, 3}))?",
     "options": ["A) list", "B) dict", "C) set", "D) tuple"], "answer": "C"},
    
    {"question": "23. Which method removes all items from a list?",
     "options": ["A) del()", "B) remove()", "C) clear()", "D) discard()"], "answer": "C"},
    
    {"question": "24. Which of these is a valid way to access the value of a dictionary key?",
     "options": ["A) dict.key", "B) dict['key']", "C) dict(key)", "D) dict::key"], "answer": "B"},
    
    {"question": "25. Which keyword checks for membership in a set?",
     "options": ["A) check", "B) exists", "C) in", "D) has"], "answer": "C"},

    # Strings and string operations
    {"question": "26. What does the upper() method do to a string?",
     "options": ["A) Capitalizes the first letter", "B) Converts to lowercase", "C) Converts to uppercase", "D) Reverses the string"], "answer": "C"},
    
    {"question": "27. Which method is used to join elements of a list into a string?",
     "options": ["A) join()", "B) concat()", "C) merge()", "D) connect()"], "answer": "A"},
    
    {"question": "28. How do you find the length of a string?",
     "options": ["A) len()", "B) size()", "C) count()", "D) length()"], "answer": "A"},
    
    {"question": "29. What is the output of 'Python'[0]?",
     "options": ["A) 'P'", "B) 'y'", "C) 't'", "D) 'h'"], "answer": "A"},
    
    {"question": "30. Which operator is used for string concatenation?",
     "options": ["A) *", "B) &", "C) +", "D) %"], "answer": "C"},

    # File handling
    {"question": "31. How do you open a file for reading in Python?",
     "options": ["A) open(file, 'r')", "B) open(file, 'w')", "C) open(file, 'a')", "D) open(file, 'x')"], "answer": "A"},
    
    {"question": "32. Which function writes to a file?",
     "options": ["A) file.write()", "B) file.print()", "C) file.read()", "D) file.insert()"], "answer": "A"},
    
    {"question": "33. How do you close a file?",
     "options": ["A) file.exit()", "B) file.close()", "C) close(file)", "D) exit(file)"], "answer": "B"},
    
    {"question": "34. What does the read() method do?",
     "options": ["A) Closes a file", "B) Writes to a file", "C) Reads a file", "D) Opens a file"], "answer": "C"},
    
    {"question": "35. How do you check if a file exists?",
     "options": ["A) with os.exists()", "B) os.isfile()", "C) os.path.exists()", "D) file.exists()"], "answer": "C"},

    # Object-oriented programming
    {"question": "36. What is a class in Python?",
     "options": ["A) A blueprint for creating objects", "B) A data type", "C) A function", "D) A module"], "answer": "A"},
    
    {"question": "37. What is the purpose of the __init__ method?",
     "options": ["A) Initializes a class", "B) Initializes an instance", "C) Creates a class", "D) Deletes an instance"], "answer": "B"},
    
    {"question": "38. Which keyword is used for inheritance in Python?",
     "options": ["A) inherits", "B) extends", "C) is", "D) from"], "answer": "D"},
    
    {"question": "39. What does the super() function do?",
     "options": ["A) Calls the parent class", "B) Initializes an instance", "C) Creates a class", "D) Defines a method"], "answer": "A"},
    
    {"question": "40. What is the output of isinstance(obj, class)?",
     "options": ["A) Checks if obj is a subclass", "B) Checks if obj is an instance", "C) Instantiates a class", "D) Creates a class"], "answer": "B"},

    # More advanced topics
    {"question": "41. What is a lambda function?",
     "options": ["A) A named function", "B) An anonymous function", "C) A built-in function", "D) A standard function"], "answer": "B"},
    
    {"question": "42. What does the map() function do?",
     "options": ["A) Filters items", "B) Applies a function to all items", "C) Reduces items", "D) Sorts items"], "answer": "B"},
    
    {"question": "43. How do you import a module in Python?",
     "options": ["A) import module", "B) include module", "C) from module import", "D) require module"], "answer": "A"},
    
    {"question": "44. Which statement is used to handle exceptions in Python?",
     "options": ["A) handle", "B) try", "C) catch", "D) exception"], "answer": "B"},
    
    {"question": "45. What is the purpose of the 'self' keyword in a class?",
     "options": ["A) Refers to the class itself", "B) Refers to the instance of the class", "C) Refers to the parent class", "D) Refers to the global scope"], "answer": "B"},
    
    {"question": "46. What is an object in Python?",
     "options": ["A) An instance of a class", "B) A variable", "C) A function", "D) A method"], "answer": "A"},
    
    {"question": "47. What is list comprehension?",
     "options": ["A) A method to create lists", "B) A method to filter lists", "C) A way to loop through lists", "D) A type of function"], "answer": "A"},
    
    {"question": "48. What is the output of [1, 2, 3] + [4, 5]?",
     "options": ["A) [1, 2, 3, 4, 5]", "B) [1, 2, 3][4, 5]", "C) [1, 2, 3, 4][5]", "D) Error"], "answer": "A"},
    
    {"question": "49. What method can be used to convert a list into a string?",
     "options": ["A) str()", "B) join()", "C) merge()", "D) concat()"], "answer": "B"},
    
    {"question": "50. Which of the following is used to handle files in Python?",
     "options": ["A) open()", "B) create()", "C) file()", "D) access()"], "answer": "A"},
]

# Function to run the quiz
def run_quiz(questions):
    score = 0  # Initialize score

    print("Welcome to the Python Programming Quiz!\n")
    
    for q in questions:
        # Display question and options
        print(q["question"])
        for option in q["options"]:
            print(option)
        
        # Get user's answer
        user_answer = input("Your answer (A, B, C, or D): ").upper()
        
        # Check if the answer is correct
        if user_answer == q["answer"]:
            print("Correct!\n")
            score += 1  # Increment score for correct answer
        else:
            print(f"Incorrect. The correct answer was {q['answer']}.\n")
    
    # Display final score
    print(f"Quiz Complete! Your final score is: {score} out of {len(questions)}")
    print(f"You scored {(score / len(questions)) * 100:.2f}%")

# Run the quiz
run_quiz(quiz_questions)
# Out:
# Welcome to the Python Programming Quiz!
#
# 1. What is the correct file extension for Python files?
# A) .pyth
# B) .pt
# C) .py
# D) .pyt
# Your answer (A, B, C, or D): C
# Correct!
#
# 2. Which keyword is used to create a function in Python?
# A) func
# B) def
# C) function
# D) define
# Your answer (A, B, C, or D): B
# Correct!
#
# 3. What is the output of print(2 ** 3)?
# A) 5
# B) 6
# C) 8
# D) 9
# Your answer (A, B, C, or D): C
# Correct!
#
# 4. How do you insert comments in Python code?
# A) // comment
# B) /* comment */
# C) # comment
# D) <!-- comment -->
# Your answer (A, B, C, or D): A
# Incorrect. The correct answer was C.
#
# 5. Which of the following data types is immutable?
# A) List
# B) Dictionary
# C) Set
# D) Tuple
# Your answer (A, B, C, or D): D
# Correct!
#
# 6. What does the len() function do?
# A) Returns the length of an object
# B) Converts object to integer
# C) Sums up all elements
# D) Sorts the object
# Your answer (A, B, C, or D): A
# Correct!
#
# ...
